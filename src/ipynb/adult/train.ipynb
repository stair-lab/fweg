# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pickle
import os
import tensorflow as tf
import numpy as np
import pandas as pd

BASE_DIR = '../../../'
import sys
sys.path.append(BASE_DIR)

# custom code
import utils.utils
CONFIG = utils.utils.load_config("../../config.json")
# Out:
# Using TensorFlow backend.

# %%
DATASET = os.path.basename(os.getcwd()) # name of folder this file is in
RANDOM_SEED = CONFIG['random_seed']
EPOCHS = CONFIG["experiment_configs"][DATASET]["epochs"]
BATCH_SIZE = CONFIG["experiment_configs"][DATASET]["batch_size"]

print(RANDOM_SEED)

PROCESSED_DIR = os.path.join(BASE_DIR, f'processed/{DATASET}/rs={RANDOM_SEED}')
MODELS_DIR = os.path.join(BASE_DIR, f'models/{DATASET}/rs={RANDOM_SEED}')

BASE_MODEL_SAVEPATH = utils.utils.get_savepath(MODELS_DIR, DATASET, ".h5", mt="base") # mt = model_type

if os.path.exists(BASE_MODEL_SAVEPATH):
    print(f"warning: model has been done for rs={RANDOM_SEED}")
# Out:
# 55
# warning: model has been done for rs=55

# %%
train_df = pd.read_csv(os.path.join(PROCESSED_DIR, "train.csv"))
hyper_train_df = pd.read_csv(os.path.join(PROCESSED_DIR, "hyper_train.csv"))
val_df = pd.read_csv(os.path.join(PROCESSED_DIR, "val.csv"))
hyper_val_df = pd.read_csv(os.path.join(PROCESSED_DIR, "hyper_val.csv"))
test_df = pd.read_csv(os.path.join(PROCESSED_DIR, "test.csv"))

val_full_df = pd.concat([val_df, hyper_val_df])

# %%
x_train = train_df.drop('label', axis=1).values
y_train = train_df['label'].values

x_hyper_train = hyper_train_df.drop('label', axis=1).values
y_hyper_train = hyper_train_df['label'].values

x_val_full = val_full_df.drop('label', axis=1).values
y_val_full = val_full_df['label'].values

x_test = test_df.drop('label', axis=1).values
y_test = test_df['label'].values

# %%
y_train = tf.keras.utils.to_categorical(y_train)
y_hyper_train = tf.keras.utils.to_categorical(y_hyper_train)
y_val_full = tf.keras.utils.to_categorical(y_val_full)
y_test = tf.keras.utils.to_categorical(y_test)

# %%
model = tf.keras.models.Sequential([
    tf.keras.Input(shape=x_train.shape[1]),
    tf.keras.layers.Dense(2, activation=tf.nn.softmax),
])

# %%
model.compile(optimizer='sgd', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# Need to save the best model by validation loss
save_best = tf.keras.callbacks.ModelCheckpoint(
    filepath=BASE_MODEL_SAVEPATH,
    monitor="val_loss",
    mode='min',
    verbose=1,
    save_best_only=True,
    save_weights_only=True,
)

callbacks = [save_best]

# %%
model.fit(
    x_train,
    y_train,
    batch_size = BATCH_SIZE,
    epochs = EPOCHS,
    validation_data = (x_hyper_train, y_hyper_train),
    callbacks=callbacks,
)
# Out:
# Epoch 1/100
# 676/682 [============================>.] - ETA: 0s - loss: 0.6218 - accuracy: 0.6471
# Epoch 00001: val_loss improved from inf to 0.55548, saving model to ../../../models/adult/rs=55/adult_mt=base.h5
# 682/682 [==============================] - 2s 2ms/step - loss: 0.6217 - accuracy: 0.6475 - val_loss: 0.5555 - val_accuracy: 0.7222
# Epoch 2/100
# 650/682 [===========================>..] - ETA: 0s - loss: 0.5386 - accuracy: 0.7329
# Epoch 00002: val_loss improved from 0.55548 to 0.52252, saving model to ../../../models/adult/rs=55/adult_mt=base.h5
# 682/682 [==============================] - 2s 2ms/step - loss: 0.5392 - accuracy: 0.7322 - val_loss: 0.5225 - val_accuracy: 0.7425
# Epoch 3/100
# 654/682 [===========================>..] - ETA: 0s - loss: 0.5208 - accuracy: 0.7442
# Epoch 00003: val_loss improved from 0.52252 to 0.51156, saving model to ../../../models/adult/rs=55/adult_mt=base.h5
# 682/682 [==============================] - 2s 2ms/step - loss: 0.5196 - accuracy: 0.7455 - val_loss: 0.5116 - val_accuracy: 0.7481
# Epoch 4/100
# 670/682 [============================>.] - ETA: 0s - loss: 0.5123 - accuracy: 0.7479
# Epoch 00004: val_loss improved from 0.51156 to 0.50599, saving model to ../../../models/adult/rs=55/adult_mt=base.h5
# 682/682 [==============================] - 2s 2ms/step - loss: 0.5118 - accuracy: 0.7485 - val_loss: 0.5060 - val_accuracy: 0.7502
# Epoch 5/100
# 666/682 [============================>.] - ETA: 0s - loss: 0.5080 - accuracy: 0.7491
# Epoch 00005: val_loss improved from 0.50599 to 0.50321, saving model to ../../../models/adult/rs=55/adult_mt=base.h5
# 682/682 [==============================] - 2s 2ms/step - loss: 0.5077 - accuracy: 0.7495 - val_loss: 0.5032 - val_accuracy: 0.7529
# Epoch 6/100
# 665/682 [============================>.] - ETA: 0s - loss: 0.5047 - accuracy: 0.7513
# Epoch 00006: val_loss improved from 0.50321 to 0.50096, saving model to ../../../models/adult/rs=55/adult_mt=base.h5
# 682/682 [==============================] - 2s 2ms/step - loss: 0.5053 - accuracy: 0.7513 - val_loss: 0.5010 - val_accuracy: 0.7529
# Epoch 7/100
# 682/682 [==============================] - ETA: 0s - loss: 0.5037 - accuracy: 0.7526
# Epoch 00007: val_loss improved from 0.50096 to 0.50023, saving model to ../../../models/adult/rs=55/adult_mt=base.h5
# 682/682 [==============================] - 2s 2ms/step - loss: 0.5037 - accuracy: 0.7526 - val_loss: 0.5002 - val_accuracy: 0.7543
# Epoch 8/100
# 661/682 [============================>.] - ETA: 0s - loss: 0.5023 - accuracy: 0.7538
# Epoch 00008: val_loss improved from 0.50023 to 0.49910, saving model to ../../../models/adult/rs=55/adult_mt=base.h5
# 682/682 [==============================] - 2s 2ms/step - loss: 0.5024 - accuracy: 0.7532 - val_loss: 0.4991 - val_accuracy: 0.7551
# Epoch 9/100
# 672/682 [============================>.] - ETA: 0s - loss: 0.5011 - accuracy: 0.7538
# Epoch 00009: val_loss improved from 0.49910 to 0.49794, saving model to ../../../models/adult/rs=55/adult_mt=base.h5
# 682/682 [==============================] - 2s 2ms/step - loss: 0.5014 - accuracy: 0.7536 - val_loss: 0.4979 - val_accuracy: 0.7575
# Epoch 10/100
# 676/682 [============================>.] - ETA: 0s - loss: 0.5006 - accuracy: 0.7539
# Epoch 00010: val_loss improved from 0.49794 to 0.49743, saving model to ../../../models/adult/rs=55/adult_mt=base.h5
# 682/682 [==============================] - 2s 2ms/step - loss: 0.5008 - accuracy: 0.7541 - val_loss: 0.4974 - val_accuracy: 0.7577
# Epoch 11/100
# 674/682 [============================>.] - ETA: 0s - loss: 0.5003 - accuracy: 0.7549
# Epoch 00011: val_loss improved from 0.49743 to 0.49688, saving model to ../../../models/adult/rs=55/adult_mt=base.h5
# 682/682 [==============================] - 2s 2ms/step - loss: 0.5001 - accuracy: 0.7548 - val_loss: 0.4969 - val_accuracy: 0.7580
# Epoch 12/100
# 670/682 [============================>.] - ETA: 0s - loss: 0.4995 - accuracy: 0.7555
# Epoch 00012: val_loss improved from 0.49688 to 0.49658, saving model to ../../../models/adult/rs=55/adult_mt=base.h5
# 682/682 [==============================] - 2s 2ms/step - loss: 0.4996 - accuracy: 0.7559 - val_loss: 0.4966 - val_accuracy: 0.7599
# Epoch 13/100
# 666/682 [============================>.] - ETA: 0s - loss: 0.4988 - accuracy: 0.7560
# Epoch 00013: val_loss improved from 0.49658 to 0.49636, saving model to ../../../models/adult/rs=55/adult_mt=base.h5
# 682/682 [==============================] - 2s 2ms/step - loss: 0.4992 - accuracy: 0.7555 - val_loss: 0.4964 - val_accuracy: 0.7580
# Epoch 14/100
# 676/682 [============================>.] - ETA: 0s - loss: 0.4984 - accuracy: 0.7567
# Epoch 00014: val_loss improved from 0.49636 to 0.49610, saving model to ../../../models/adult/rs=55/adult_mt=base.h5
# 682/682 [==============================] - 2s 2ms/step - loss: 0.4988 - accuracy: 0.7564 - val_loss: 0.4961 - val_accuracy: 0.7577
# Epoch 15/100
# 668/682 [============================>.] - ETA: 0s - loss: 0.4982 - accuracy: 0.7569
# Epoch 00015: val_loss improved from 0.49610 to 0.49592, saving model to ../../../models/adult/rs=55/adult_mt=base.h5
# 682/682 [==============================] - 2s 2ms/step - loss: 0.4985 - accuracy: 0.7568 - val_loss: 0.4959 - val_accuracy: 0.7573
# Epoch 16/100
# 670/682 [============================>.] - ETA: 0s - loss: 0.4977 - accuracy: 0.7556
# Epoch 00016: val_loss improved from 0.49592 to 0.49554, saving model to ../../../models/adult/rs=55/adult_mt=base.h5
# 682/682 [==============================] - 2s 2ms/step - loss: 0.4982 - accuracy: 0.7555 - val_loss: 0.4955 - val_accuracy: 0.7593
# Epoch 17/100
# 654/682 [===========================>..] - ETA: 0s - loss: 0.4985 - accuracy: 0.7559
# Epoch 00017: val_loss improved from 0.49554 to 0.49536, saving model to ../../../models/adult/rs=55/adult_mt=base.h5
# 682/682 [==============================] - 2s 2ms/step - loss: 0.4980 - accuracy: 0.7568 - val_loss: 0.4954 - val_accuracy: 0.7594
# Epoch 18/100
# 664/682 [============================>.] - ETA: 0s - loss: 0.4983 - accuracy: 0.7561
# Epoch 00018: val_loss improved from 0.49536 to 0.49524, saving model to ../../../models/adult/rs=55/adult_mt=base.h5
# 682/682 [==============================] - 2s 2ms/step - loss: 0.4977 - accuracy: 0.7564 - val_loss: 0.4952 - val_accuracy: 0.7596
# Epoch 19/100
# 665/682 [============================>.] - ETA: 0s - loss: 0.4977 - accuracy: 0.7557
# Epoch 00019: val_loss improved from 0.49524 to 0.49510, saving model to ../../../models/adult/rs=55/adult_mt=base.h5
# 682/682 [==============================] - 2s 2ms/step - loss: 0.4976 - accuracy: 0.7554 - val_loss: 0.4951 - val_accuracy: 0.7590
# Epoch 20/100
# 669/682 [============================>.] - ETA: 0s - loss: 0.4972 - accuracy: 0.7558
# Epoch 00020: val_loss improved from 0.49510 to 0.49507, saving model to ../../../models/adult/rs=55/adult_mt=base.h5
# 682/682 [==============================] - 2s 2ms/step - loss: 0.4973 - accuracy: 0.7558 - val_loss: 0.4951 - val_accuracy: 0.7594
# Epoch 21/100
# 668/682 [============================>.] - ETA: 0s - loss: 0.4972 - accuracy: 0.7548
# Epoch 00021: val_loss improved from 0.49507 to 0.49494, saving model to ../../../models/adult/rs=55/adult_mt=base.h5
# 682/682 [==============================] - 2s 2ms/step - loss: 0.4973 - accuracy: 0.7552 - val_loss: 0.4949 - val_accuracy: 0.7589
# Epoch 22/100
# 671/682 [============================>.] - ETA: 0s - loss: 0.4976 - accuracy: 0.7559
# Epoch 00022: val_loss improved from 0.49494 to 0.49493, saving model to ../../../models/adult/rs=55/adult_mt=base.h5
# 682/682 [==============================] - 2s 2ms/step - loss: 0.4971 - accuracy: 0.7563 - val_loss: 0.4949 - val_accuracy: 0.7603
# Epoch 23/100
# 665/682 [============================>.] - ETA: 0s - loss: 0.4981 - accuracy: 0.7573
# Epoch 00023: val_loss did not improve from 0.49493
# 682/682 [==============================] - 2s 2ms/step - loss: 0.4969 - accuracy: 0.7577 - val_loss: 0.4951 - val_accuracy: 0.7581
# Epoch 24/100
# 659/682 [===========================>..] - ETA: 0s - loss: 0.4969 - accuracy: 0.7564
# Epoch 00024: val_loss did not improve from 0.49493
# 682/682 [==============================] - 2s 2ms/step - loss: 0.4969 - accuracy: 0.7564 - val_loss: 0.4949 - val_accuracy: 0.7587
# Epoch 25/100
# 666/682 [============================>.] - ETA: 0s - loss: 0.4968 - accuracy: 0.7571
# Epoch 00025: val_loss did not improve from 0.49493
# 682/682 [==============================] - 2s 2ms/step - loss: 0.4967 - accuracy: 0.7569 - val_loss: 0.4952 - val_accuracy: 0.7574
# Epoch 26/100
# 663/682 [============================>.] - ETA: 0s - loss: 0.4970 - accuracy: 0.7576
# Epoch 00026: val_loss improved from 0.49493 to 0.49473, saving model to ../../../models/adult/rs=55/adult_mt=base.h5
# 682/682 [==============================] - 2s 2ms/step - loss: 0.4966 - accuracy: 0.7579 - val_loss: 0.4947 - val_accuracy: 0.7609
# Epoch 27/100
# 653/682 [===========================>..] - ETA: 0s - loss: 0.4976 - accuracy: 0.7571
# Epoch 00027: val_loss improved from 0.49473 to 0.49439, saving model to ../../../models/adult/rs=55/adult_mt=base.h5
# 682/682 [==============================] - 2s 2ms/step - loss: 0.4966 - accuracy: 0.7577 - val_loss: 0.4944 - val_accuracy: 0.7600
# Epoch 28/100
# 663/682 [============================>.] - ETA: 0s - loss: 0.4958 - accuracy: 0.7574
# Epoch 00028: val_loss did not improve from 0.49439
# 682/682 [==============================] - 2s 2ms/step - loss: 0.4964 - accuracy: 0.7570 - val_loss: 0.4945 - val_accuracy: 0.7607
# Epoch 29/100
# 654/682 [===========================>..] - ETA: 0s - loss: 0.4967 - accuracy: 0.7573
# Epoch 00029: val_loss improved from 0.49439 to 0.49431, saving model to ../../../models/adult/rs=55/adult_mt=base.h5
# 682/682 [==============================] - 2s 2ms/step - loss: 0.4964 - accuracy: 0.7571 - val_loss: 0.4943 - val_accuracy: 0.7597
# Epoch 30/100
# 676/682 [============================>.] - ETA: 0s - loss: 0.4961 - accuracy: 0.7573
# Epoch 00030: val_loss improved from 0.49431 to 0.49426, saving model to ../../../models/adult/rs=55/adult_mt=base.h5
# 682/682 [==============================] - 2s 2ms/step - loss: 0.4962 - accuracy: 0.7574 - val_loss: 0.4943 - val_accuracy: 0.7599
# Epoch 31/100
# 674/682 [============================>.] - ETA: 0s - loss: 0.4968 - accuracy: 0.7571
# Epoch 00031: val_loss improved from 0.49426 to 0.49420, saving model to ../../../models/adult/rs=55/adult_mt=base.h5
# 682/682 [==============================] - 2s 2ms/step - loss: 0.4962 - accuracy: 0.7573 - val_loss: 0.4942 - val_accuracy: 0.7604
# Epoch 32/100
# 670/682 [============================>.] - ETA: 0s - loss: 0.4973 - accuracy: 0.7574
# Epoch 00032: val_loss did not improve from 0.49420
# 682/682 [==============================] - 2s 2ms/step - loss: 0.4961 - accuracy: 0.7582 - val_loss: 0.4943 - val_accuracy: 0.7598
# Epoch 33/100
# 655/682 [===========================>..] - ETA: 0s - loss: 0.4962 - accuracy: 0.7579
# Epoch 00033: val_loss improved from 0.49420 to 0.49418, saving model to ../../../models/adult/rs=55/adult_mt=base.h5
# 682/682 [==============================] - 2s 2ms/step - loss: 0.4961 - accuracy: 0.7574 - val_loss: 0.4942 - val_accuracy: 0.7605
# Epoch 34/100
# 656/682 [===========================>..] - ETA: 0s - loss: 0.4965 - accuracy: 0.7584
# Epoch 00034: val_loss did not improve from 0.49418
# 682/682 [==============================] - 2s 2ms/step - loss: 0.4959 - accuracy: 0.7588 - val_loss: 0.4943 - val_accuracy: 0.7596
# Epoch 35/100
# 667/682 [============================>.] - ETA: 0s - loss: 0.4962 - accuracy: 0.7577
# Epoch 00035: val_loss improved from 0.49418 to 0.49411, saving model to ../../../models/adult/rs=55/adult_mt=base.h5
# 682/682 [==============================] - 2s 2ms/step - loss: 0.4959 - accuracy: 0.7579 - val_loss: 0.4941 - val_accuracy: 0.7607
# Epoch 36/100
# 662/682 [============================>.] - ETA: 0s - loss: 0.4953 - accuracy: 0.7580
# Epoch 00036: val_loss did not improve from 0.49411
# 682/682 [==============================] - 2s 2ms/step - loss: 0.4959 - accuracy: 0.7578 - val_loss: 0.4943 - val_accuracy: 0.7594
# Epoch 37/100
# 667/682 [============================>.] - ETA: 0s - loss: 0.4965 - accuracy: 0.7577
# Epoch 00037: val_loss did not improve from 0.49411
# 682/682 [==============================] - 2s 2ms/step - loss: 0.4959 - accuracy: 0.7585 - val_loss: 0.4942 - val_accuracy: 0.7590
# Epoch 38/100
# 674/682 [============================>.] - ETA: 0s - loss: 0.4961 - accuracy: 0.7573
# Epoch 00038: val_loss improved from 0.49411 to 0.49399, saving model to ../../../models/adult/rs=55/adult_mt=base.h5
# 682/682 [==============================] - 2s 2ms/step - loss: 0.4958 - accuracy: 0.7576 - val_loss: 0.4940 - val_accuracy: 0.7605
# Epoch 39/100
# 662/682 [============================>.] - ETA: 0s - loss: 0.4960 - accuracy: 0.7579
# Epoch 00039: val_loss did not improve from 0.49399
# 682/682 [==============================] - 2s 2ms/step - loss: 0.4957 - accuracy: 0.7582 - val_loss: 0.4941 - val_accuracy: 0.7595
# Epoch 40/100
# 677/682 [============================>.] - ETA: 0s - loss: 0.4959 - accuracy: 0.7595
# Epoch 00040: val_loss improved from 0.49399 to 0.49393, saving model to ../../../models/adult/rs=55/adult_mt=base.h5
# 682/682 [==============================] - 2s 2ms/step - loss: 0.4957 - accuracy: 0.7594 - val_loss: 0.4939 - val_accuracy: 0.7602
# Epoch 41/100
# 667/682 [============================>.] - ETA: 0s - loss: 0.4959 - accuracy: 0.7589
# Epoch 00041: val_loss improved from 0.49393 to 0.49385, saving model to ../../../models/adult/rs=55/adult_mt=base.h5
# 682/682 [==============================] - 2s 2ms/step - loss: 0.4955 - accuracy: 0.7593 - val_loss: 0.4938 - val_accuracy: 0.7603
# Epoch 42/100
# 673/682 [============================>.] - ETA: 0s - loss: 0.4953 - accuracy: 0.7586
# Epoch 00042: val_loss did not improve from 0.49385
# 682/682 [==============================] - 2s 2ms/step - loss: 0.4956 - accuracy: 0.7580 - val_loss: 0.4939 - val_accuracy: 0.7605
# Epoch 43/100
# 681/682 [============================>.] - ETA: 0s - loss: 0.4953 - accuracy: 0.7595
# Epoch 00043: val_loss did not improve from 0.49385
# 682/682 [==============================] - 2s 2ms/step - loss: 0.4956 - accuracy: 0.7593 - val_loss: 0.4939 - val_accuracy: 0.7603
# Epoch 44/100
# 675/682 [============================>.] - ETA: 0s - loss: 0.4956 - accuracy: 0.7578
# Epoch 00044: val_loss did not improve from 0.49385
# 682/682 [==============================] - 2s 2ms/step - loss: 0.4954 - accuracy: 0.7579 - val_loss: 0.4943 - val_accuracy: 0.7595
# Epoch 45/100
# 675/682 [============================>.] - ETA: 0s - loss: 0.4960 - accuracy: 0.7585
# Epoch 00045: val_loss did not improve from 0.49385
# 682/682 [==============================] - 2s 2ms/step - loss: 0.4955 - accuracy: 0.7589 - val_loss: 0.4941 - val_accuracy: 0.7600
# Epoch 46/100
# 675/682 [============================>.] - ETA: 0s - loss: 0.4954 - accuracy: 0.7583
# Epoch 00046: val_loss did not improve from 0.49385
# 682/682 [==============================] - 2s 2ms/step - loss: 0.4954 - accuracy: 0.7586 - val_loss: 0.4939 - val_accuracy: 0.7594
# Epoch 47/100
# 679/682 [============================>.] - ETA: 0s - loss: 0.4949 - accuracy: 0.7592
# Epoch 00047: val_loss improved from 0.49385 to 0.49372, saving model to ../../../models/adult/rs=55/adult_mt=base.h5
# 682/682 [==============================] - 2s 2ms/step - loss: 0.4954 - accuracy: 0.7590 - val_loss: 0.4937 - val_accuracy: 0.7601
# Epoch 48/100
# 680/682 [============================>.] - ETA: 0s - loss: 0.4954 - accuracy: 0.7582
# Epoch 00048: val_loss did not improve from 0.49372
# 682/682 [==============================] - 2s 2ms/step - loss: 0.4954 - accuracy: 0.7581 - val_loss: 0.4940 - val_accuracy: 0.7596
# Epoch 49/100
# 675/682 [============================>.] - ETA: 0s - loss: 0.4952 - accuracy: 0.7588
# Epoch 00049: val_loss did not improve from 0.49372
# 682/682 [==============================] - 2s 2ms/step - loss: 0.4953 - accuracy: 0.7588 - val_loss: 0.4939 - val_accuracy: 0.7598
# Epoch 50/100
# 672/682 [============================>.] - ETA: 0s - loss: 0.4960 - accuracy: 0.7580
# Epoch 00050: val_loss did not improve from 0.49372
# 682/682 [==============================] - 2s 2ms/step - loss: 0.4953 - accuracy: 0.7587 - val_loss: 0.4945 - val_accuracy: 0.7588
# Epoch 51/100
# 663/682 [============================>.] - ETA: 0s - loss: 0.4944 - accuracy: 0.7603
# Epoch 00051: val_loss improved from 0.49372 to 0.49371, saving model to ../../../models/adult/rs=55/adult_mt=base.h5
# 682/682 [==============================] - 2s 2ms/step - loss: 0.4952 - accuracy: 0.7597 - val_loss: 0.4937 - val_accuracy: 0.7600
# Epoch 52/100
# 669/682 [============================>.] - ETA: 0s - loss: 0.4962 - accuracy: 0.7575
# Epoch 00052: val_loss did not improve from 0.49371
# 682/682 [==============================] - 2s 2ms/step - loss: 0.4953 - accuracy: 0.7582 - val_loss: 0.4938 - val_accuracy: 0.7599
# Epoch 53/100
# 682/682 [==============================] - ETA: 0s - loss: 0.4952 - accuracy: 0.7595
# Epoch 00053: val_loss improved from 0.49371 to 0.49363, saving model to ../../../models/adult/rs=55/adult_mt=base.h5
# 682/682 [==============================] - 2s 2ms/step - loss: 0.4952 - accuracy: 0.7595 - val_loss: 0.4936 - val_accuracy: 0.7598
# Epoch 54/100
# 674/682 [============================>.] - ETA: 0s - loss: 0.4947 - accuracy: 0.7589
# Epoch 00054: val_loss did not improve from 0.49363
# 682/682 [==============================] - 2s 2ms/step - loss: 0.4951 - accuracy: 0.7587 - val_loss: 0.4938 - val_accuracy: 0.7599
# Epoch 55/100
# 655/682 [===========================>..] - ETA: 0s - loss: 0.4951 - accuracy: 0.7589
# Epoch 00055: val_loss did not improve from 0.49363
# 682/682 [==============================] - 2s 2ms/step - loss: 0.4951 - accuracy: 0.7586 - val_loss: 0.4937 - val_accuracy: 0.7595
# Epoch 56/100
# 678/682 [============================>.] - ETA: 0s - loss: 0.4955 - accuracy: 0.7578
# Epoch 00056: val_loss improved from 0.49363 to 0.49355, saving model to ../../../models/adult/rs=55/adult_mt=base.h5
# 682/682 [==============================] - 2s 2ms/step - loss: 0.4951 - accuracy: 0.7582 - val_loss: 0.4936 - val_accuracy: 0.7597
# Epoch 57/100
# 668/682 [============================>.] - ETA: 0s - loss: 0.4957 - accuracy: 0.7585
# Epoch 00057: val_loss improved from 0.49355 to 0.49354, saving model to ../../../models/adult/rs=55/adult_mt=base.h5
# 682/682 [==============================] - 2s 2ms/step - loss: 0.4950 - accuracy: 0.7591 - val_loss: 0.4935 - val_accuracy: 0.7595
# Epoch 58/100
# 676/682 [============================>.] - ETA: 0s - loss: 0.4949 - accuracy: 0.7586
# Epoch 00058: val_loss improved from 0.49354 to 0.49352, saving model to ../../../models/adult/rs=55/adult_mt=base.h5
# 682/682 [==============================] - 2s 2ms/step - loss: 0.4951 - accuracy: 0.7587 - val_loss: 0.4935 - val_accuracy: 0.7597
# Epoch 59/100
# 678/682 [============================>.] - ETA: 0s - loss: 0.4947 - accuracy: 0.7594
# Epoch 00059: val_loss did not improve from 0.49352
# 682/682 [==============================] - 2s 2ms/step - loss: 0.4950 - accuracy: 0.7592 - val_loss: 0.4936 - val_accuracy: 0.7593
# Epoch 60/100
# 651/682 [===========================>..] - ETA: 0s - loss: 0.4950 - accuracy: 0.7591
# Epoch 00060: val_loss improved from 0.49352 to 0.49351, saving model to ../../../models/adult/rs=55/adult_mt=base.h5
# 682/682 [==============================] - 2s 2ms/step - loss: 0.4949 - accuracy: 0.7588 - val_loss: 0.4935 - val_accuracy: 0.7601
# Epoch 61/100
# 675/682 [============================>.] - ETA: 0s - loss: 0.4951 - accuracy: 0.7590
# Epoch 00061: val_loss did not improve from 0.49351
# 682/682 [==============================] - 2s 2ms/step - loss: 0.4949 - accuracy: 0.7592 - val_loss: 0.4937 - val_accuracy: 0.7593
# Epoch 62/100
# 682/682 [==============================] - ETA: 0s - loss: 0.4949 - accuracy: 0.7593
# Epoch 00062: val_loss did not improve from 0.49351
# 682/682 [==============================] - 2s 2ms/step - loss: 0.4949 - accuracy: 0.7593 - val_loss: 0.4942 - val_accuracy: 0.7597
# Epoch 63/100
# 667/682 [============================>.] - ETA: 0s - loss: 0.4948 - accuracy: 0.7599
# Epoch 00063: val_loss did not improve from 0.49351
# 682/682 [==============================] - 2s 2ms/step - loss: 0.4949 - accuracy: 0.7601 - val_loss: 0.4936 - val_accuracy: 0.7596
# Epoch 64/100
# 659/682 [===========================>..] - ETA: 0s - loss: 0.4953 - accuracy: 0.7583
# Epoch 00064: val_loss did not improve from 0.49351
# 682/682 [==============================] - 2s 2ms/step - loss: 0.4948 - accuracy: 0.7584 - val_loss: 0.4942 - val_accuracy: 0.7595
# Epoch 65/100
# 661/682 [============================>.] - ETA: 0s - loss: 0.4937 - accuracy: 0.7595
# Epoch 00065: val_loss did not improve from 0.49351
# 682/682 [==============================] - 2s 2ms/step - loss: 0.4948 - accuracy: 0.7593 - val_loss: 0.4935 - val_accuracy: 0.7594
# Epoch 66/100
# 673/682 [============================>.] - ETA: 0s - loss: 0.4952 - accuracy: 0.7586
# Epoch 00066: val_loss did not improve from 0.49351
# 682/682 [==============================] - 2s 2ms/step - loss: 0.4948 - accuracy: 0.7585 - val_loss: 0.4942 - val_accuracy: 0.7594
# Epoch 67/100
# 661/682 [============================>.] - ETA: 0s - loss: 0.4954 - accuracy: 0.7582
# Epoch 00067: val_loss did not improve from 0.49351
# 682/682 [==============================] - 2s 2ms/step - loss: 0.4948 - accuracy: 0.7588 - val_loss: 0.4936 - val_accuracy: 0.7592
# Epoch 68/100
# 653/682 [===========================>..] - ETA: 0s - loss: 0.4941 - accuracy: 0.7597
# Epoch 00068: val_loss improved from 0.49351 to 0.49339, saving model to ../../../models/adult/rs=55/adult_mt=base.h5
# 682/682 [==============================] - 2s 2ms/step - loss: 0.4946 - accuracy: 0.7592 - val_loss: 0.4934 - val_accuracy: 0.7596
# Epoch 69/100
# 680/682 [============================>.] - ETA: 0s - loss: 0.4945 - accuracy: 0.7599
# Epoch 00069: val_loss did not improve from 0.49339
# 682/682 [==============================] - 2s 2ms/step - loss: 0.4947 - accuracy: 0.7597 - val_loss: 0.4935 - val_accuracy: 0.7591
# Epoch 70/100
# 674/682 [============================>.] - ETA: 0s - loss: 0.4952 - accuracy: 0.7586
# Epoch 00070: val_loss did not improve from 0.49339
# 682/682 [==============================] - 2s 2ms/step - loss: 0.4946 - accuracy: 0.7588 - val_loss: 0.4936 - val_accuracy: 0.7592
# Epoch 71/100
# 675/682 [============================>.] - ETA: 0s - loss: 0.4951 - accuracy: 0.7588
# Epoch 00071: val_loss improved from 0.49339 to 0.49335, saving model to ../../../models/adult/rs=55/adult_mt=base.h5
# 682/682 [==============================] - 2s 2ms/step - loss: 0.4947 - accuracy: 0.7589 - val_loss: 0.4934 - val_accuracy: 0.7603
# Epoch 72/100
# 654/682 [===========================>..] - ETA: 0s - loss: 0.4942 - accuracy: 0.7591
# Epoch 00072: val_loss improved from 0.49335 to 0.49331, saving model to ../../../models/adult/rs=55/adult_mt=base.h5
# 682/682 [==============================] - 2s 2ms/step - loss: 0.4946 - accuracy: 0.7588 - val_loss: 0.4933 - val_accuracy: 0.7593
# Epoch 73/100
# 678/682 [============================>.] - ETA: 0s - loss: 0.4949 - accuracy: 0.7585
# Epoch 00073: val_loss did not improve from 0.49331
# 682/682 [==============================] - 2s 2ms/step - loss: 0.4946 - accuracy: 0.7588 - val_loss: 0.4933 - val_accuracy: 0.7594
# Epoch 74/100
# 660/682 [============================>.] - ETA: 0s - loss: 0.4949 - accuracy: 0.7589
# Epoch 00074: val_loss did not improve from 0.49331
# 682/682 [==============================] - 2s 2ms/step - loss: 0.4946 - accuracy: 0.7595 - val_loss: 0.4934 - val_accuracy: 0.7590
# Epoch 75/100
# 657/682 [===========================>..] - ETA: 0s - loss: 0.4949 - accuracy: 0.7596
# Epoch 00075: val_loss did not improve from 0.49331
# 682/682 [==============================] - 2s 2ms/step - loss: 0.4946 - accuracy: 0.7595 - val_loss: 0.4938 - val_accuracy: 0.7594
# Epoch 76/100
# 664/682 [============================>.] - ETA: 0s - loss: 0.4945 - accuracy: 0.7584
# Epoch 00076: val_loss did not improve from 0.49331
# 682/682 [==============================] - 2s 2ms/step - loss: 0.4946 - accuracy: 0.7581 - val_loss: 0.4934 - val_accuracy: 0.7590
# Epoch 77/100
# 671/682 [============================>.] - ETA: 0s - loss: 0.4949 - accuracy: 0.7602
# Epoch 00077: val_loss did not improve from 0.49331
# 682/682 [==============================] - 2s 2ms/step - loss: 0.4946 - accuracy: 0.7608 - val_loss: 0.4934 - val_accuracy: 0.7593
# Epoch 78/100
# 661/682 [============================>.] - ETA: 0s - loss: 0.4947 - accuracy: 0.7596
# Epoch 00078: val_loss did not improve from 0.49331
# 682/682 [==============================] - 2s 2ms/step - loss: 0.4944 - accuracy: 0.7597 - val_loss: 0.4940 - val_accuracy: 0.7592
# Epoch 79/100
# 678/682 [============================>.] - ETA: 0s - loss: 0.4949 - accuracy: 0.7591
# Epoch 00079: val_loss did not improve from 0.49331
# 682/682 [==============================] - 2s 2ms/step - loss: 0.4946 - accuracy: 0.7594 - val_loss: 0.4936 - val_accuracy: 0.7588
# Epoch 80/100
# 674/682 [============================>.] - ETA: 0s - loss: 0.4949 - accuracy: 0.7580
# Epoch 00080: val_loss did not improve from 0.49331
# 682/682 [==============================] - 2s 2ms/step - loss: 0.4944 - accuracy: 0.7582 - val_loss: 0.4936 - val_accuracy: 0.7592
# Epoch 81/100
# 677/682 [============================>.] - ETA: 0s - loss: 0.4942 - accuracy: 0.7599
# Epoch 00081: val_loss did not improve from 0.49331
# 682/682 [==============================] - 2s 2ms/step - loss: 0.4943 - accuracy: 0.7597 - val_loss: 0.4950 - val_accuracy: 0.7591
# Epoch 82/100
# 664/682 [============================>.] - ETA: 0s - loss: 0.4952 - accuracy: 0.7572
# Epoch 00082: val_loss improved from 0.49331 to 0.49329, saving model to ../../../models/adult/rs=55/adult_mt=base.h5
# 682/682 [==============================] - 2s 2ms/step - loss: 0.4945 - accuracy: 0.7577 - val_loss: 0.4933 - val_accuracy: 0.7588
# Epoch 83/100
# 660/682 [============================>.] - ETA: 0s - loss: 0.4942 - accuracy: 0.7594
# Epoch 00083: val_loss did not improve from 0.49329
# 682/682 [==============================] - 2s 2ms/step - loss: 0.4944 - accuracy: 0.7592 - val_loss: 0.4935 - val_accuracy: 0.7594
# Epoch 84/100
# 660/682 [============================>.] - ETA: 0s - loss: 0.4947 - accuracy: 0.7588
# Epoch 00084: val_loss improved from 0.49329 to 0.49324, saving model to ../../../models/adult/rs=55/adult_mt=base.h5
# 682/682 [==============================] - 2s 2ms/step - loss: 0.4944 - accuracy: 0.7592 - val_loss: 0.4932 - val_accuracy: 0.7594
# Epoch 85/100
# 652/682 [===========================>..] - ETA: 0s - loss: 0.4944 - accuracy: 0.7588
# Epoch 00085: val_loss did not improve from 0.49324
# 682/682 [==============================] - 2s 2ms/step - loss: 0.4944 - accuracy: 0.7587 - val_loss: 0.4933 - val_accuracy: 0.7590
# Epoch 86/100
# 681/682 [============================>.] - ETA: 0s - loss: 0.4943 - accuracy: 0.7589
# Epoch 00086: val_loss improved from 0.49324 to 0.49317, saving model to ../../../models/adult/rs=55/adult_mt=base.h5
# 682/682 [==============================] - 2s 2ms/step - loss: 0.4943 - accuracy: 0.7589 - val_loss: 0.4932 - val_accuracy: 0.7591
# Epoch 87/100
# 650/682 [===========================>..] - ETA: 0s - loss: 0.4937 - accuracy: 0.7595
# Epoch 00087: val_loss did not improve from 0.49317
# 682/682 [==============================] - 2s 2ms/step - loss: 0.4943 - accuracy: 0.7587 - val_loss: 0.4932 - val_accuracy: 0.7598
# Epoch 88/100
# 653/682 [===========================>..] - ETA: 0s - loss: 0.4953 - accuracy: 0.7586
# Epoch 00088: val_loss improved from 0.49317 to 0.49313, saving model to ../../../models/adult/rs=55/adult_mt=base.h5
# 682/682 [==============================] - 2s 2ms/step - loss: 0.4943 - accuracy: 0.7593 - val_loss: 0.4931 - val_accuracy: 0.7590
# Epoch 89/100
# 676/682 [============================>.] - ETA: 0s - loss: 0.4944 - accuracy: 0.7593
# Epoch 00089: val_loss improved from 0.49313 to 0.49311, saving model to ../../../models/adult/rs=55/adult_mt=base.h5
# 682/682 [==============================] - 2s 2ms/step - loss: 0.4943 - accuracy: 0.7594 - val_loss: 0.4931 - val_accuracy: 0.7595
# Epoch 90/100
# 675/682 [============================>.] - ETA: 0s - loss: 0.4942 - accuracy: 0.7595
# Epoch 00090: val_loss did not improve from 0.49311
# 682/682 [==============================] - 2s 2ms/step - loss: 0.4942 - accuracy: 0.7595 - val_loss: 0.4933 - val_accuracy: 0.7595
# Epoch 91/100
# 680/682 [============================>.] - ETA: 0s - loss: 0.4941 - accuracy: 0.7596
# Epoch 00091: val_loss did not improve from 0.49311
# 682/682 [==============================] - 2s 2ms/step - loss: 0.4942 - accuracy: 0.7595 - val_loss: 0.4931 - val_accuracy: 0.7596
# Epoch 92/100
# 656/682 [===========================>..] - ETA: 0s - loss: 0.4946 - accuracy: 0.7590
# Epoch 00092: val_loss improved from 0.49311 to 0.49309, saving model to ../../../models/adult/rs=55/adult_mt=base.h5
# 682/682 [==============================] - 2s 2ms/step - loss: 0.4943 - accuracy: 0.7590 - val_loss: 0.4931 - val_accuracy: 0.7590
# Epoch 93/100
# 670/682 [============================>.] - ETA: 0s - loss: 0.4945 - accuracy: 0.7590
# Epoch 00093: val_loss did not improve from 0.49309
# 682/682 [==============================] - 2s 2ms/step - loss: 0.4940 - accuracy: 0.7593 - val_loss: 0.4932 - val_accuracy: 0.7595
# Epoch 94/100
# 679/682 [============================>.] - ETA: 0s - loss: 0.4943 - accuracy: 0.7591
# Epoch 00094: val_loss did not improve from 0.49309
# 682/682 [==============================] - 2s 2ms/step - loss: 0.4941 - accuracy: 0.7589 - val_loss: 0.4934 - val_accuracy: 0.7587
# Epoch 95/100
# 669/682 [============================>.] - ETA: 0s - loss: 0.4950 - accuracy: 0.7581
# Epoch 00095: val_loss improved from 0.49309 to 0.49306, saving model to ../../../models/adult/rs=55/adult_mt=base.h5
# 682/682 [==============================] - 2s 2ms/step - loss: 0.4942 - accuracy: 0.7591 - val_loss: 0.4931 - val_accuracy: 0.7586
# Epoch 96/100
# 673/682 [============================>.] - ETA: 0s - loss: 0.4948 - accuracy: 0.7587
# Epoch 00096: val_loss did not improve from 0.49306
# 682/682 [==============================] - 2s 2ms/step - loss: 0.4941 - accuracy: 0.7591 - val_loss: 0.4931 - val_accuracy: 0.7593
# Epoch 97/100
# 657/682 [===========================>..] - ETA: 0s - loss: 0.4933 - accuracy: 0.7601
# Epoch 00097: val_loss did not improve from 0.49306
# 682/682 [==============================] - 2s 2ms/step - loss: 0.4942 - accuracy: 0.7593 - val_loss: 0.4931 - val_accuracy: 0.7585
# Epoch 98/100
# 680/682 [============================>.] - ETA: 0s - loss: 0.4938 - accuracy: 0.7608
# Epoch 00098: val_loss did not improve from 0.49306
# 682/682 [==============================] - 2s 2ms/step - loss: 0.4940 - accuracy: 0.7609 - val_loss: 0.4941 - val_accuracy: 0.7594
# Epoch 99/100
# 669/682 [============================>.] - ETA: 0s - loss: 0.4948 - accuracy: 0.7576
# Epoch 00099: val_loss did not improve from 0.49306
# 682/682 [==============================] - 2s 2ms/step - loss: 0.4941 - accuracy: 0.7580 - val_loss: 0.4932 - val_accuracy: 0.7585
# Epoch 100/100
# 653/682 [===========================>..] - ETA: 0s - loss: 0.4954 - accuracy: 0.7601
# Epoch 00100: val_loss did not improve from 0.49306
# 682/682 [==============================] - 2s 2ms/step - loss: 0.4940 - accuracy: 0.7607 - val_loss: 0.4940 - val_accuracy: 0.7596

# %%
# see the best saved
model.load_weights(BASE_MODEL_SAVEPATH)

# %%
# train acc
preds_train = utils.utils.compute_preds(
    model,
    x_train,
    batch_size=BATCH_SIZE,
)
(np.argmax(preds_train, axis=1) == np.argwhere(y_train)[:,1]).mean()
# Out:
# 0.7602108640843457

# %%
# hyper train acc
preds_hyper_train = utils.utils.compute_preds(
    model,
    x_hyper_train,
    batch_size=BATCH_SIZE,
)
(np.argmax(preds_hyper_train, axis=1) == np.argwhere(y_hyper_train)[:,1]).mean()
# Out:
# 0.758607854085241

# %%
# val acc
preds_val_full = utils.utils.compute_preds(
    model,
    x_val_full,
    batch_size=BATCH_SIZE,
)
(np.argmax(preds_val_full, axis=1) == np.argwhere(y_val_full)[:,1]).mean()
# Out:
# 0.6319018404907976

# %%
# test acc
preds_test = utils.utils.compute_preds(
    model,
    x_test,
    batch_size=BATCH_SIZE,
)
(np.argmax(preds_test, axis=1) == np.argwhere(y_test)[:,1]).mean()
# Out:
# 0.6192455639657526
